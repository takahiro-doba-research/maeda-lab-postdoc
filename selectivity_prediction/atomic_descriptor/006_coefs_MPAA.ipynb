# %%
file_read = "004_fit_MPAA"
file_write = "006_coefs_MPAA"

# %%
import polars as pl

df_coefs = pl.read_parquet(f"{file_read}_coefs.parquet")

# %%
n_features_min = 83

# %%
df_coefs_ = df_coefs.filter(pl.col("n_features") == n_features_min)

# %%
df_coefs_
# Out:
# shape: (8, 89)
# ┌────────────┬────────────┬───────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ backbone_t ┆ n_features ┆ alpha ┆ backbone_h ┆ … ┆ pyridone_ ┆ pyridone_ ┆ pyridone_ ┆ pyridone_ │
# │ est        ┆ ---        ┆ ---   ┆ omo        ┆   ┆ vbur_labe ┆ B1_label3 ┆ B5_label3 ┆ L_label3  │
# │ ---        ┆ i32        ┆ f64   ┆ ---        ┆   ┆ l3        ┆ ---       ┆ ---       ┆ ---       │
# │ i32        ┆            ┆       ┆ f64        ┆   ┆ ---       ┆ f64       ┆ f64       ┆ f64       │
# │            ┆            ┆       ┆            ┆   ┆ f64       ┆           ┆           ┆           │
# ╞════════════╪════════════╪═══════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 0          ┆ 83         ┆ 0.01  ┆ -0.025219  ┆ … ┆ -0.063134 ┆ 0.068096  ┆ 0.026256  ┆ -0.030797 │
# │ 1          ┆ 83         ┆ 0.01  ┆ -0.017838  ┆ … ┆ -0.063641 ┆ 0.069312  ┆ 0.025242  ┆ -0.029053 │
# │ 2          ┆ 83         ┆ 0.01  ┆ -0.01915   ┆ … ┆ -0.061827 ┆ 0.0669    ┆ 0.029995  ┆ -0.029163 │
# │ 3          ┆ 83         ┆ 0.01  ┆ -0.024805  ┆ … ┆ -0.05696  ┆ 0.05993   ┆ 0.022682  ┆ -0.028507 │
# │ 4          ┆ 83         ┆ 0.01  ┆ -0.021398  ┆ … ┆ -0.056238 ┆ 0.060142  ┆ 0.022861  ┆ -0.028288 │
# │ 5          ┆ 83         ┆ 0.01  ┆ 0.014176   ┆ … ┆ -0.122791 ┆ 0.147088  ┆ 0.037243  ┆ -0.030706 │
# │ 19         ┆ 83         ┆ 0.01  ┆ -0.025044  ┆ … ┆ -0.049147 ┆ 0.060085  ┆ 0.023563  ┆ -0.030456 │
# │ 20         ┆ 83         ┆ 0.01  ┆ -0.039524  ┆ … ┆ -0.065496 ┆ 0.0814    ┆ 0.02392   ┆ -0.026759 │
# └────────────┴────────────┴───────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
columns_feat = [col for col in df_coefs_.columns if col.startswith(("pyridone_", "backbone_")) and col != "backbone_test"]

# %%
data = df_coefs_[columns_feat].to_numpy()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(figsize=(16, 4), dpi=300)

im = ax.imshow(data, vmin=-0.7, vmax=0.7, cmap="coolwarm")

ax.set_xlabel("Features")
ax.set_ylabel("MPAA")
ax.set_xticks(np.arange(data.shape[1]))
ax.set_yticks(np.arange(data.shape[0]))
ax.set_xticklabels([c.replace("backbone", "mpaa")for c in columns_feat], rotation=90)
ax.set_yticklabels(df_coefs_["backbone_test"])

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.1)
fig.colorbar(im, cax=cax)

plt.savefig(
    f"{file_write}_imshow.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()

# %%
data_mean = df_coefs_[columns_feat].fill_null(0.0).mean().to_numpy().ravel()
data_std = df_coefs_[columns_feat].fill_null(0.0).std(ddof=1).to_numpy().ravel()
data_std = np.where(data_std == 0.0, np.nan, data_std)

# %%
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(16, 3), dpi=300)

norm = mcolors.TwoSlopeNorm(vcenter=0.0, vmin=-0.5, vmax=0.5)
colors = plt.cm.coolwarm(norm(data_mean))
error_kw = dict(elinewidth=0.8, capthick=0.8)
ax.bar(
    np.arange(len(data_mean)),
    data_mean,
    yerr=data_std,
    color=colors,
    capsize=2.5,
    error_kw=error_kw
)
ax.axhline(0, color="gray", linewidth=0.8)

ax.set_xlabel("Features")
ax.set_ylabel("Coefficient")
ax.set_xticks(np.arange(len(data_mean)))
ax.set_xticklabels([c.replace("backbone", "mpaa")for c in columns_feat], rotation=90)
ax.margins(x=0.003)
ax.set_ylim(-0.20, 0.20)

plt.savefig(
    f"{file_write}_bar.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()

# %%
data_mean
# Out:
# array([-0.01985002, -0.00744021, -0.0114996 ,  0.01829001,  0.03040053,
#        -0.00883412, -0.00710656, -0.01697583, -0.04052765,  0.009263  ,
#        -0.02191116, -0.02548136, -0.01173596, -0.07237773,  0.10183915,
#         0.03306634, -0.01082745, -0.04943428, -0.01769226,  0.08303569,
#         0.01286572,  0.06021661,  0.00387232, -0.00697215,  0.        ,
#         0.01979229, -0.0639505 , -0.03159728,  0.04794515,  0.01273729,
#        -0.07111291,  0.03258514,  0.03908815, -0.05195934, -0.01679688,
#        -0.07539487,  0.10183926,  0.02731007,  0.01484887, -0.00346364,
#        -0.00528292, -0.03688569, -0.02316451, -0.0302859 ,  0.03625521,
#        -0.01880837,  0.        ,  0.02862774, -0.00876421, -0.0538718 ,
#         0.00140582,  0.07419953, -0.01204763,  0.05592482, -0.01349261,
#        -0.00232835,  0.05333386, -0.0556044 ,  0.10909232,  0.03692584,
#         0.06568338,  0.03216466,  0.04594846,  0.03869211,  0.0204825 ,
#         0.00854265, -0.03388079, -0.08067308, -0.02688337,  0.02690832,
#        -0.06857376,  0.06390872,  0.        ,  0.02230657,  0.01916829,
#         0.05570055,  0.08302966,  0.1026775 ,  0.07107186, -0.05631593,
#        -0.04684899, -0.04083221, -0.06740414,  0.07661898,  0.02647027,
#        -0.02921616])
