# %%
file_read = "007_fit_random"
file_write = "009_coefs_random"

# %%
import polars as pl

df_coefs = pl.read_parquet(f"{file_read}_coefs.parquet")

# %%
n_features_min = 44

# %%
df_coefs_ = df_coefs.filter(pl.col("n_features") == n_features_min)

# %%
df_coefs_
# Out:
# shape: (13, 54)
# ┌──────────────┬────────────┬────────┬───────────┬───┬───────────┬──────────┬───────────┬──────────┐
# │ pyridone_tes ┆ n_features ┆ alpha  ┆ 2_zero    ┆ … ┆ 597_zero  ┆ 602_zero ┆ 605_zero  ┆ 642_zero │
# │ t            ┆ ---        ┆ ---    ┆ ---       ┆   ┆ ---       ┆ ---      ┆ ---       ┆ ---      │
# │ ---          ┆ i32        ┆ f64    ┆ f64       ┆   ┆ f64       ┆ f64      ┆ f64       ┆ f64      │
# │ i32          ┆            ┆        ┆           ┆   ┆           ┆          ┆           ┆          │
# ╞══════════════╪════════════╪════════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪══════════╡
# │ 0            ┆ 44         ┆ 199.99 ┆ -0.014431 ┆ … ┆ null      ┆ null     ┆ -0.008523 ┆ 0.006313 │
# │ 1            ┆ 44         ┆ 199.99 ┆ -0.013069 ┆ … ┆ null      ┆ 0.008507 ┆ -0.002424 ┆ 0.002887 │
# │ 2            ┆ 44         ┆ 199.99 ┆ -0.014885 ┆ … ┆ null      ┆ 0.004693 ┆ -0.003804 ┆ 0.009091 │
# │ 3            ┆ 44         ┆ 199.99 ┆ -0.025214 ┆ … ┆ -0.00521  ┆ 0.007251 ┆ null      ┆ 0.005576 │
# │ 4            ┆ 44         ┆ 199.99 ┆ -0.016513 ┆ … ┆ null      ┆ 0.009553 ┆ -0.004506 ┆ 0.00841  │
# │ …            ┆ …          ┆ …      ┆ …         ┆ … ┆ …         ┆ …        ┆ …         ┆ …        │
# │ 8            ┆ 44         ┆ 199.99 ┆ -0.021103 ┆ … ┆ null      ┆ 0.007077 ┆ -0.006521 ┆ null     │
# │ 9            ┆ 44         ┆ 199.99 ┆ -0.01946  ┆ … ┆ -0.001968 ┆ 0.011182 ┆ null      ┆ 0.009555 │
# │ 10           ┆ 44         ┆ 199.99 ┆ -0.02388  ┆ … ┆ -0.003993 ┆ 0.009825 ┆ -0.004081 ┆ 0.004765 │
# │ 11           ┆ 44         ┆ 199.99 ┆ -0.015588 ┆ … ┆ null      ┆ 0.014958 ┆ 0.009067  ┆ 0.012137 │
# │ 12           ┆ 44         ┆ 199.99 ┆ -0.017696 ┆ … ┆ null      ┆ 0.005471 ┆ -0.006907 ┆ 0.010532 │
# └──────────────┴────────────┴────────┴───────────┴───┴───────────┴──────────┴───────────┴──────────┘

# %%
columns_feat = [column for column in df_coefs_.columns if "zero" in column]

# %%
data = df_coefs_[columns_feat].to_numpy()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(figsize=(12, 4), dpi=300)

im = ax.imshow(data, vmin=-0.7, vmax=0.7, cmap="coolwarm")

ax.set_xlabel("Intermediate")
ax.set_ylabel("Pyridone")
ax.set_xticks(np.arange(data.shape[1]))
ax.set_yticks(np.arange(data.shape[0]))
ax.set_xticklabels([c[:-5] for c in columns_feat], rotation=90)
ax.set_yticklabels(df_coefs_["pyridone_test"])

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.1)
fig.colorbar(im, cax=cax)

plt.savefig(
    f"{file_write}_imshow.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()

# %%
data_mean = df_coefs_[columns_feat].fill_null(0.0).mean().to_numpy().ravel()
data_std = df_coefs_[columns_feat].fill_null(0.0).std(ddof=1).to_numpy().ravel()
data_std = np.where(data_std == 0.0, np.nan, data_std)

# %%
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(12, 3), dpi=300)

norm = mcolors.TwoSlopeNorm(vcenter=0.0, vmin=-0.5, vmax=0.5)
colors = plt.cm.coolwarm(norm(data_mean))
error_kw = dict(elinewidth=0.8, capthick=0.8)
ax.bar(
    np.arange(len(data_mean)),
    data_mean,
    yerr=data_std,
    color=colors,
    capsize=2.5,
    error_kw=error_kw
)
ax.axhline(0, color="gray", linewidth=0.8)

ax.set_xlabel("Intermediate")
ax.set_ylabel("Coefficient")
ax.set_xticks(np.arange(len(data_mean)))
ax.set_xticklabels([c[:-5] for c in columns_feat], rotation=90)
ax.margins(x=0.003)
ax.set_ylim(-1.0, 1.0)

plt.savefig(
    f"{file_write}_bar.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()
