# %%
file_read = "001_fit"
file_write = "003_coefs"

# %%
import polars as pl

df_coefs = pl.read_parquet(f"{file_read}_coefs.parquet")

# %%
df_coefs
# Out:
# shape: (153, 54)
# ┌───────────────┬────────────┬───────┬───────────┬───┬───────────┬──────────┬──────────┬──────────┐
# │ pyridone_test ┆ n_features ┆ alpha ┆ 2_zero    ┆ … ┆ 597_zero  ┆ 602_zero ┆ 605_zero ┆ 642_zero │
# │ ---           ┆ ---        ┆ ---   ┆ ---       ┆   ┆ ---       ┆ ---      ┆ ---      ┆ ---      │
# │ i32           ┆ i32        ┆ f64   ┆ f64       ┆   ┆ f64       ┆ f64      ┆ f64      ┆ f64      │
# ╞═══════════════╪════════════╪═══════╪═══════════╪═══╪═══════════╪══════════╪══════════╪══════════╡
# │ 0             ┆ 51         ┆ 0.01  ┆ -0.02593  ┆ … ┆ -0.201031 ┆ -0.0     ┆ -0.0     ┆ 0.0      │
# │ 0             ┆ 19         ┆ 0.01  ┆ -0.025906 ┆ … ┆ -0.201046 ┆ null     ┆ null     ┆ null     │
# │ 0             ┆ 18         ┆ 0.01  ┆ -0.047926 ┆ … ┆ -0.188286 ┆ null     ┆ null     ┆ null     │
# │ 0             ┆ 17         ┆ 0.01  ┆ -0.084195 ┆ … ┆ -0.174074 ┆ null     ┆ null     ┆ null     │
# │ 0             ┆ 16         ┆ 0.01  ┆ -0.062228 ┆ … ┆ -0.113382 ┆ null     ┆ null     ┆ null     │
# │ …             ┆ …          ┆ …     ┆ …         ┆ … ┆ …         ┆ …        ┆ …        ┆ …        │
# │ 12            ┆ 9          ┆ 0.01  ┆ null      ┆ … ┆ null      ┆ null     ┆ null     ┆ null     │
# │ 12            ┆ 8          ┆ 0.02  ┆ null      ┆ … ┆ null      ┆ null     ┆ null     ┆ null     │
# │ 12            ┆ 7          ┆ 0.02  ┆ null      ┆ … ┆ null      ┆ null     ┆ null     ┆ null     │
# │ 12            ┆ 6          ┆ 0.03  ┆ null      ┆ … ┆ null      ┆ null     ┆ null     ┆ null     │
# │ 12            ┆ 5          ┆ 0.01  ┆ null      ┆ … ┆ null      ┆ null     ┆ null     ┆ null     │
# └───────────────┴────────────┴───────┴───────────┴───┴───────────┴──────────┴──────────┴──────────┘

# %%
n_features_min = 15

# %%
df_coefs_ = df_coefs.filter(pl.col("n_features") == n_features_min)

# %%
df_coefs_
# Out:
# shape: (7, 54)
# ┌───────────────┬────────────┬───────┬───────────┬───┬───────────┬──────────┬───────────┬──────────┐
# │ pyridone_test ┆ n_features ┆ alpha ┆ 2_zero    ┆ … ┆ 597_zero  ┆ 602_zero ┆ 605_zero  ┆ 642_zero │
# │ ---           ┆ ---        ┆ ---   ┆ ---       ┆   ┆ ---       ┆ ---      ┆ ---       ┆ ---      │
# │ i32           ┆ i32        ┆ f64   ┆ f64       ┆   ┆ f64       ┆ f64      ┆ f64       ┆ f64      │
# ╞═══════════════╪════════════╪═══════╪═══════════╪═══╪═══════════╪══════════╪═══════════╪══════════╡
# │ 0             ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.139861 ┆ null     ┆ null      ┆ null     │
# │ 3             ┆ 15         ┆ 0.01  ┆ -0.319467 ┆ … ┆ null      ┆ null     ┆ null      ┆ null     │
# │ 5             ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.540611 ┆ null     ┆ -0.065801 ┆ null     │
# │ 6             ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.150818 ┆ null     ┆ null      ┆ null     │
# │ 7             ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.351963 ┆ null     ┆ null      ┆ null     │
# │ 10            ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.112356 ┆ null     ┆ null      ┆ null     │
# │ 12            ┆ 15         ┆ 0.01  ┆ null      ┆ … ┆ -0.222622 ┆ null     ┆ null      ┆ null     │
# └───────────────┴────────────┴───────┴───────────┴───┴───────────┴──────────┴───────────┴──────────┘

# %%
columns_feat = [column for column in df_coefs_.columns if "zero" in column]

# %%
data = df_coefs_[columns_feat].to_numpy()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(figsize=(12, 4), dpi=300)

im = ax.imshow(data, vmin=-0.7, vmax=0.7, cmap="coolwarm")

ax.set_xlabel("Intermediate")
ax.set_ylabel("Pyridone")
ax.set_xticks(np.arange(data.shape[1]))
ax.set_yticks(np.arange(data.shape[0]))
ax.set_xticklabels([c[:-5] for c in columns_feat], rotation=90)
ax.set_yticklabels(df_coefs_["pyridone_test"])

divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.1)
fig.colorbar(im, cax=cax)

plt.savefig(
    f"{file_write}_imshow.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()

# %%
data_mean = df_coefs_[columns_feat].fill_null(0.0).mean().to_numpy().ravel()
data_std = df_coefs_[columns_feat].fill_null(0.0).std(ddof=1).to_numpy().ravel()
data_std = np.where(data_std == 0.0, np.nan, data_std)

# %%
import matplotlib.colors as mcolors

fig, ax = plt.subplots(figsize=(12, 3), dpi=300)

norm = mcolors.TwoSlopeNorm(vcenter=0.0, vmin=-0.5, vmax=0.5)
colors = plt.cm.coolwarm(norm(data_mean))
error_kw = dict(elinewidth=0.8, capthick=0.8)
ax.bar(
    np.arange(len(data_mean)),
    data_mean,
    yerr=data_std,
    color=colors,
    capsize=2.5,
    error_kw=error_kw
)
ax.axhline(0, color="gray", linewidth=0.8)

ax.set_xlabel("Intermediate")
ax.set_ylabel("Coefficient")
ax.set_xticks(np.arange(len(data_mean)))
ax.set_xticklabels([c[:-5] for c in columns_feat], rotation=90)
ax.margins(x=0.003)
ax.set_ylim(-0.6, 0.6)

plt.savefig(
    f"{file_write}_bar.png",
    transparent=True,
    bbox_inches="tight",
    pad_inches=0.1
)
plt.show()
